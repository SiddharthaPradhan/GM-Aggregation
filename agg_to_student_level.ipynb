# %%
import pandas as pd

# %%
attempt_processed_df = pd.read_csv('./output/agg_attempt_merged_df.csv')

# %%
attempt_processed_df['stars'].unique()
# Out:
# array([ 3.,  2., nan,  1.])

# %%
attempt_processed_df['stars_1'] = attempt_processed_df['stars'] == 1
attempt_processed_df['stars_2'] = attempt_processed_df['stars'] == 2
attempt_processed_df['stars_3'] = attempt_processed_df['stars'] == 3
attempt_processed_df['stars_NA'] = attempt_processed_df['stars'].isna()

# %%
student_problem_df = attempt_processed_df.groupby(['studentRef', 'taskNumber']).agg(
        attempts=('attemptNumber', 'max'),
        total_replays=('replay_attempt', 'sum'),
        completed_attempts=('completed_dur_attempt', 'sum'),
        num_errors=('num_errors', 'sum'),
        num_hints=('num_hints', 'sum'),
        total_time_spent=('timeSpent', 'sum'),
        total_three_star=('stars_3', 'sum'),
        total_two_star=('stars_2', 'sum'),
        total_one_star=('stars_1', 'sum'),
        total_incomplete=('stars_NA', 'sum'),
        avg_stars=('stars', 'mean')
).reset_index()
student_problem_df['completed_attempts'] = student_problem_df['completed_attempts'].fillna(0).astype(int)
student_problem_df['total_replays'] = student_problem_df['total_replays'].fillna(
    0).astype(int)

# %%
student_problem_df.to_csv('./output/student_problem_level.csv', index=False)

# %%
student_df  = student_problem_df.groupby('studentRef').agg(
    total_problems=('taskNumber', 'nunique'),
    total_attempts=('attempts', 'sum'),
    total_replays=('total_replays', 'sum'),
    total_completed_attempts=('completed_attempts', 'sum'),
    total_errors=('num_errors', 'sum'),
    total_hints=('num_hints', 'sum'),
    total_time_spent=('total_time_spent', 'sum'),
    total_one_star=('total_one_star', 'sum'),
    total_two_star=('total_two_star', 'sum'),
    total_three_star=('total_three_star', 'sum'),
    total_incomplete=('total_incomplete', 'sum'),
    avg_stars=('avg_stars', 'mean')
).reset_index()

# %%
student_df
# Out:
#                    studentRef  total_problems  total_attempts  total_replays  \
# 0    689a3db5a5a0dcb0efbfe0d9              10            11.0              1
# 1    689a5eb0339d724c4b85064d              12            15.0              0
# 2    689b48fea5a0dcb0efc03e13               3             3.0              0
# 3    689b5fd0a5a0dcb0efc04b46              36            36.0              0
# 4    689b6c59a5a0dcb0efc04ecd              18            23.0              1
# ..                        ...             ...             ...            ...
# 804  68dfefd323d0a54e09102418               9            14.0              3
# 805  68dff13e23d0a54e091138eb              36            72.0             10
# 806  68dff2bd7fb9e1f6ac52192e               6             6.0              0
# 807  68e0069ef946085e8444873c               9            20.0              1
# 808  68e0069ff946085e84448abb              29            45.0              2
#
#      total_completed_attempts  total_errors  total_hints  total_time_spent  \
# 0                          10             2            0           104.412
# 1                          11             2            0           325.132
# 2                           2             0            0            24.316
# 3                          36             4            1           396.308
# 4                          19             9            0           942.350
# ..                        ...           ...          ...               ...
# 804                        10             2            0           179.141
# 805                        42            54            2          1456.857
# 806                         5             1            0           121.705
# 807                         8            52            1           479.015
# 808                        30            13            4          1152.321
#
#      total_one_star  total_two_star  total_three_star  avg_stars
# 0                 0               4                 6   2.611111
# 1                 0               1                10   2.909091
# 2                 0               0                 2   3.000000
# 3                 0               3                33   2.916667
# 4                 1               8                10   2.527778
# ..              ...             ...               ...        ...
# 804               0               2                 8   2.875000
# 805               0               7                35   2.921429
# 806               0               2                 3   2.600000
# 807               0               4                 4   2.500000
# 808               2              14                14   2.428571
#
# [809 rows x 12 columns]

# %%
student_df.describe()
# Out:
#        total_problems  total_attempts  total_replays  \
# count      809.000000      809.000000     809.000000
# mean        42.223733       71.767614      11.957973
# std         34.226902       70.642896      25.343447
# min          1.000000        1.000000       0.000000
# 25%         21.000000       39.000000       1.000000
# 50%         33.000000       55.000000       5.000000
# 75%         50.000000       77.000000      14.000000
# max        252.000000      769.000000     319.000000
#
#        total_completed_attempts  total_errors  total_hints  total_time_spent  \
# count                809.000000    809.000000   809.000000        809.000000
# mean                  48.301607     57.049444     5.503090       1812.383827
# std                   43.743067     70.206573    10.248173       2330.470817
# min                    1.000000      0.000000     0.000000         22.308000
# 25%                   25.000000     25.000000     0.000000       1141.628000
# 50%                   36.000000     42.000000     3.000000       1513.016000
# 75%                   55.000000     64.000000     7.000000       1815.611000
# max                  409.000000    975.000000   191.000000      50614.276000
#
#        total_one_star  total_two_star  total_three_star   avg_stars
# count      809.000000      809.000000        809.000000  809.000000
# mean         1.580964       11.254635         35.466007    2.722293
# std          2.523392        9.811815         34.288802    0.189071
# min          0.000000        0.000000          0.000000    1.900000
# 25%          0.000000        6.000000         15.000000    2.607143
# 50%          1.000000       10.000000         25.000000    2.772727
# 75%          2.000000       13.000000         41.000000    2.875000
# max         30.000000      125.000000        291.000000    3.000000

# %%
student_df['total_time_spent_mins'] = student_df['total_time_spent'] / 60

# %%
student_df.to_csv('./output/student_level_agg.csv', index=False)

# %%
student_df.describe().to_csv('./output/student_level_agg_summary.csv')

# %%
data_folder = "data/research-data-68dc2e6975d58c3b44b947d5-2025-10-02/"

roster_df = pd.read_json(data_folder+'roster-metadata.json')

# %%
roster_df
# Out:
#                     sessionId                studentRef  \
# 0    689b80e9a5a0dcb0efc05a22  689a3bab339d724c4b84f220
# 1    689b80e9a5a0dcb0efc05a22  689a3db5a5a0dcb0efbfe0d9
# 2    689b80e9a5a0dcb0efc05a22  689a5eb0339d724c4b85064d
# 3    689b80e9a5a0dcb0efc05a22  689b445b1c2a3051d6476c5b
# 4    689b80e9a5a0dcb0efc05a22  689b48fea5a0dcb0efc03e13
# ..                        ...                       ...
# 802  68de816c9c576abf144ce9d3  68b86eec4b63ee62858f8653
# 803  68de816c9c576abf144ce9d3  68b86ef04b63ee62858f8677
# 804  68de816c9c576abf144ce9d3  68b86ef0cd608fad6b88cbf6
# 805  68de816c9c576abf144ce9d3  68b86ef14b63ee62858f8699
# 806  68de816c9c576abf144ce9d3  68b867d5b4f70f7e6b61feb3
#
#                   classroomId     studentEmailPrefix                 teacherId
# 0    689a3a351c2a3051d646fc15  pontecorvo.robert.inc  65d4cca1231a070013ea0390
# 1    689a3a351c2a3051d646fc15            erin.ottmar  65d4cca1231a070013ea0390
# 2    689a3a351c2a3051d646fc15               awortman  65d4cca1231a070013ea0390
# 3    689a3a351c2a3051d646fc15                   erik  65d4cca1231a070013ea0390
# 4    689a3a351c2a3051d646fc15                   xwei  65d4cca1231a070013ea0390
# ..                        ...                    ...                       ...
# 802  68b82ce4cd608fad6b864ace                 207450  62d9645c6c2cd30013dbd10c
# 803  68b82ce4cd608fad6b864ace                 156709  62d9645c6c2cd30013dbd10c
# 804  68b82ce4cd608fad6b864ace                 150999  62d9645c6c2cd30013dbd10c
# 805  68b82ce4cd608fad6b864ace                 153312  62d9645c6c2cd30013dbd10c
# 806  68b82ce4cd608fad6b864ace                 153732  62d9645c6c2cd30013dbd10c
#
# [807 rows x 5 columns]

# %%
completed_students = student_df.query('total_problems == 252')

# %%
completed_students
# Out:
#                    studentRef  total_problems  total_attempts  total_replays  \
# 103  68ade7cf6ac49894e3b59883             252           769.0            319
# 106  68ade7f442606a064821a5b6             252           540.0             25
# 112  68ade8146ac49894e3b5a176             252           714.0            291
#
#      total_completed_attempts  total_errors  total_hints  total_time_spent  \
# 103                       320           975           19         15875.364
# 106                       258           749          107         17811.043
# 112                       409           551           49         16217.317
#
#      total_one_star  total_two_star  total_three_star  avg_stars  \
# 103               8              59               253   2.898611
# 106              28              57               173   2.567460
# 112              30              88               291   2.846745
#
#      total_time_spent_mins
# 103             264.589400
# 106             296.850717
# 112             270.288617

# %%
completed_students.merge(roster_df, on='studentRef', how='left')
# Out:
#                  studentRef  total_problems  total_attempts  total_replays  \
# 0  68ade7cf6ac49894e3b59883             252           769.0            319
# 1  68ade7f442606a064821a5b6             252           540.0             25
# 2  68ade8146ac49894e3b5a176             252           714.0            291
#
#    total_completed_attempts  total_errors  total_hints  total_time_spent  \
# 0                       320           975           19         15875.364
# 1                       258           749          107         17811.043
# 2                       409           551           49         16217.317
#
#    total_one_star  total_two_star  total_three_star  avg_stars  \
# 0               8              59               253   2.898611
# 1              28              57               173   2.567460
# 2              30              88               291   2.846745
#
#    total_time_spent_mins                 sessionId               classroomId  \
# 0             264.589400  68daccd2b4f70f7e6bf25a3c  689b60aba5a0dcb0efc04b6c
# 1             296.850717  68daccd2b4f70f7e6bf25a3c  689b60aba5a0dcb0efc04b6c
# 2             270.288617  68daccd2b4f70f7e6bf25a3c  689b60aba5a0dcb0efc04b6c
#
#   studentEmailPrefix                 teacherId
# 0             206591  6883d08351ce0772f035172f
# 1             164963  6883d08351ce0772f035172f
# 2             154415  6883d08351ce0772f035172f
